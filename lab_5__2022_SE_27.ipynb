# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul-ur-Rehman-Butt/2022-SE-27_LAB_TASKS_ML/blob/main/lab_5__2022_SE_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
trip_data = pd.read_csv('/content/taxi_trip_pricing.csv')
trip_data.head()
# Out:
#    Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0             19.35     Morning     Weekday              3.0
# 1             47.59   Afternoon     Weekday              1.0
# 2             36.87     Evening     Weekend              1.0
# 3             30.33     Evening     Weekday              4.0
# 4               NaN     Evening     Weekday              3.0
#
#   Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                Low   Clear       3.56         0.80             0.32
# 1               High   Clear        NaN         0.62             0.43
# 2               High   Clear       2.70         1.21             0.15
# 3                Low     NaN       3.48         0.51             0.15
# 4               High   Clear       2.93         0.63             0.32
#
#    Trip_Duration_Minutes  Trip_Price
# 0                  53.82     36.2624
# 1                  40.57         NaN
# 2                  37.27     52.9032
# 3                 116.81     36.4698
# 4                  22.64     15.6180

# %%
len(trip_data)
# Out:
# 1000

# %%
trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Trip_Distance_km       950 non-null    float64
#  1   Time_of_Day            950 non-null    object
#  2   Day_of_Week            950 non-null    object
#  3   Passenger_Count        950 non-null    float64
#  4   Traffic_Conditions     950 non-null    object
#  5   Weather                950 non-null    object
#  6   Base_Fare              950 non-null    float64
#  7   Per_Km_Rate            950 non-null    float64
#  8   Per_Minute_Rate        950 non-null    float64
#  9   Trip_Duration_Minutes  950 non-null    float64
#  10  Trip_Price             951 non-null    float64
# dtypes: float64(7), object(4)
# memory usage: 86.1+ KB

# %%
trip_data.describe()
# Out:
#        Trip_Distance_km  Passenger_Count   Base_Fare  Per_Km_Rate  \
# count        950.000000       950.000000  950.000000   950.000000
# mean          27.070547         2.476842    3.502989     1.233316
# std           19.905300         1.102249    0.870162     0.429816
# min            1.230000         1.000000    2.010000     0.500000
# 25%           12.632500         1.250000    2.730000     0.860000
# 50%           25.830000         2.000000    3.520000     1.220000
# 75%           38.405000         3.000000    4.260000     1.610000
# max          146.067047         4.000000    5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes  Trip_Price
# count       950.000000             950.000000  951.000000
# mean          0.292916              62.118116   56.874773
# std           0.115592              32.154406   40.469791
# min           0.100000               5.010000    6.126900
# 25%           0.190000              35.882500   33.742650
# 50%           0.290000              61.860000   50.074500
# 75%           0.390000              89.055000   69.099350
# max           0.500000             119.840000  332.043689

# %%
# identify the numerical columns and replace the missing values with their median.

num_col = ['Trip_Distance_km','Passenger_Count','Base_Fare','Per_Km_Rate','Per_Minute_Rate','Trip_Duration_Minutes','Trip_Price']
trip_data[num_col] = trip_data[num_col].apply(lambda col: col.fillna(col.median()))

# %%
# identify the catagorical columns and replace the missing values with their mode.
# [0] means that we are taking the first mode from the data

cat_col = ['Time_of_Day','Day_of_Week','Traffic_Conditions','Weather' ]
trip_data[cat_col] = trip_data[cat_col].apply(lambda col: col.fillna(col.mode()[0]))

# %%
trip_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Trip_Distance_km       1000 non-null   float64
#  1   Time_of_Day            1000 non-null   object
#  2   Day_of_Week            1000 non-null   object
#  3   Passenger_Count        1000 non-null   float64
#  4   Traffic_Conditions     1000 non-null   object
#  5   Weather                1000 non-null   object
#  6   Base_Fare              1000 non-null   float64
#  7   Per_Km_Rate            1000 non-null   float64
#  8   Per_Minute_Rate        1000 non-null   float64
#  9   Trip_Duration_Minutes  1000 non-null   float64
#  10  Trip_Price             1000 non-null   float64
# dtypes: float64(7), object(4)
# memory usage: 86.1+ KB

# %%
plt.boxplot(trip_data['Trip_Distance_km'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73b6736390>,
#   <matplotlib.lines.Line2D at 0x7f73b6737010>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73b6986c10>,
#   <matplotlib.lines.Line2D at 0x7f73b65f8350>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73b69876d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73b65f8dd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73b65f9710>],
#  'means': []}

# %%
plt.boxplot(trip_data['Passenger_Count'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73fc3b9290>,
#   <matplotlib.lines.Line2D at 0x7f73fc3b9c90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73fc3ba6d0>,
#   <matplotlib.lines.Line2D at 0x7f73fc3bb150>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73fc3a9750>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73fc3bbb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73fc3c44d0>],
#  'means': []}

# %%
plt.boxplot(trip_data['Base_Fare'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73b40714d0>,
#   <matplotlib.lines.Line2D at 0x7f73b4071f50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73b4072690>,
#   <matplotlib.lines.Line2D at 0x7f73b4073090>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73b4070b90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73b4073a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73b4080450>],
#  'means': []}

# %%
plt.boxplot(trip_data['Per_Km_Rate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73b40d8090>,
#   <matplotlib.lines.Line2D at 0x7f73b40d8b10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73b40d9490>,
#   <matplotlib.lines.Line2D at 0x7f73b40d9e90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73b40cf790>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73b40da6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73b40dafd0>],
#  'means': []}

# %%
plt.boxplot(trip_data['Per_Minute_Rate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73b413d8d0>,
#   <matplotlib.lines.Line2D at 0x7f73b413e250>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73b413ec50>,
#   <matplotlib.lines.Line2D at 0x7f73b413f4d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73b413d010>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73b413fed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73b4148750>],
#  'means': []}

# %%
plt.boxplot(trip_data['Trip_Duration_Minutes'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73b3f9b350>,
#   <matplotlib.lines.Line2D at 0x7f73b3f9bc50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73b3fa0650>,
#   <matplotlib.lines.Line2D at 0x7f73b3fa0fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73b3f8bcd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73b3fa1a10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73b3fa2390>],
#  'means': []}

# %%
plt.boxplot(trip_data['Trip_Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73b3ff8f50>,
#   <matplotlib.lines.Line2D at 0x7f73b3ff9910>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73b3ffa0d0>,
#   <matplotlib.lines.Line2D at 0x7f73b3ffa9d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73b3ff8710>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73b3ffb350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73b3ffbc50>],
#  'means': []}

# %%
## Now the outliers are in two numerical columns that are "Trip_Distance_Km" and "Trip_Price"

# %%
# removing the outlier of "Trip_Distance_km"

col = 'Trip_Distance_km'
Q1 = trip_data[col].quantile(0.25)
Q3 = trip_data[col].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
non_outliers = trip_data[(trip_data[col] >= lower_bound) & (trip_data[col] <= upper_bound)][col]
rep_value = non_outliers.mean()
trip_data[col] = trip_data[col].where((trip_data[col] >= lower_bound) & (trip_data[col] <= upper_bound), rep_value)

# %%
plt.boxplot(trip_data['Trip_Distance_km'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73b404e390>,
#   <matplotlib.lines.Line2D at 0x7f73b404ee10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73b404f810>,
#   <matplotlib.lines.Line2D at 0x7f73b405c210>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73b404d9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73b405cc10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73b403e110>],
#  'means': []}

# %%
# removing the outlier of "Trip_Price"

col = 'Trip_Price'
Q1 = trip_data[col].quantile(0.25)
Q3 = trip_data[col].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
non_outliers = trip_data[(trip_data[col] >= lower_bound) & (trip_data[col] <= upper_bound)][col]
rep_value = non_outliers.mean()
trip_data[col] = trip_data[col].where((trip_data[col] >= lower_bound) & (trip_data[col] <= upper_bound), rep_value)

# %%
plt.boxplot(trip_data['Trip_Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f73b3ea74d0>,
#   <matplotlib.lines.Line2D at 0x7f73b3ea7e50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f73b3eb4890>,
#   <matplotlib.lines.Line2D at 0x7f73b3eb5250>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f73b3ea6ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f73b3eb5bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f73b3eb6510>],
#  'means': []}

# %%
trip_data.describe()
# Out:
#        Trip_Distance_km  Passenger_Count    Base_Fare  Per_Km_Rate  \
# count       1000.000000      1000.000000  1000.000000  1000.000000
# mean          25.097347         2.453000     3.503840     1.232650
# std           13.871576         1.079331     0.848115     0.418932
# min            1.230000         1.000000     2.010000     0.500000
# 25%           13.107500         2.000000     2.770000     0.870000
# 50%           25.830000         2.000000     3.520000     1.220000
# 75%           36.727500         3.000000     4.202500     1.580000
# max           49.990000         4.000000     5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes   Trip_Price
# count      1000.000000            1000.000000  1000.000000
# mean          0.292770              62.105210    51.284952
# std           0.112664              31.339464    22.023048
# min           0.100000               5.010000     6.126900
# 25%           0.197500              37.107500    34.578850
# 50%           0.290000              61.860000    50.074500
# 75%           0.382500              87.775000    64.724625
# max           0.500000             119.840000   109.896500

# %%
# LINEAR REGREESI0N WITH SINGLE Variable

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
trip_data.columns
# Out:
# Index(['Trip_Distance_km', 'Time_of_Day', 'Day_of_Week', 'Passenger_Count',
#        'Traffic_Conditions', 'Weather', 'Base_Fare', 'Per_Km_Rate',
#        'Per_Minute_Rate', 'Trip_Duration_Minutes', 'Trip_Price'],
#       dtype='object')

# %%
sns.distplot(trip_data['Trip_Distance_km'])
# Out:
# <Axes: xlabel='Trip_Distance_km', ylabel='Density'>

# %%
sns.distplot(trip_data['Trip_Price'])
# Out:
# <Axes: xlabel='Trip_Price', ylabel='Density'>

# %%
sns.scatterplot(x='Trip_Distance_km',y='Trip_Price',data=trip_data)
# Out:
# <Axes: xlabel='Trip_Distance_km', ylabel='Trip_Price'>

# %%
trip_data[['Trip_Distance_km', 'Passenger_Count', 'Base_Fare','Per_Km_Rate', 'Per_Minute_Rate', 'Trip_Duration_Minutes', 'Trip_Price']].corr()
# Out:
#                        Trip_Distance_km  Passenger_Count  Base_Fare  \
# Trip_Distance_km               1.000000        -0.013898   0.045475
# Passenger_Count               -0.013898         1.000000   0.019717
# Base_Fare                      0.045475         0.019717   1.000000
# Per_Km_Rate                   -0.037588         0.025258   0.002975
# Per_Minute_Rate               -0.013606         0.028360  -0.018047
# Trip_Duration_Minutes         -0.037873         0.024868   0.011585
# Trip_Price                     0.649600         0.052393   0.035950
#
#                        Per_Km_Rate  Per_Minute_Rate  Trip_Duration_Minutes  \
# Trip_Distance_km         -0.037588        -0.013606              -0.037873
# Passenger_Count           0.025258         0.028360               0.024868
# Base_Fare                 0.002975        -0.018047               0.011585
# Per_Km_Rate               1.000000         0.027585               0.025636
# Per_Minute_Rate           0.027585         1.000000              -0.022913
# Trip_Duration_Minutes     0.025636        -0.022913               1.000000
# Trip_Price                0.371449         0.244993               0.329593
#
#                        Trip_Price
# Trip_Distance_km         0.649600
# Passenger_Count          0.052393
# Base_Fare                0.035950
# Per_Km_Rate              0.371449
# Per_Minute_Rate          0.244993
# Trip_Duration_Minutes    0.329593
# Trip_Price               1.000000

# %%
X = trip_data[['Trip_Distance_km']]
Y = trip_data['Trip_Price']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
model = LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(Y_test,Y_pred)

# %%
mse
# Out:
# 271.9887563734366

# %%
np.sqrt(mse)
# Out:
# 16.492081626448392

# %%
# Scatter plot of actual data
plt.scatter(X.iloc[:, 0], Y, color='blue', label='Actual Data')

# Plot the regression line
plt.plot(X.iloc[:, 0], model.predict(X), color='red', label='Regression Line')

# Plot errors (residuals)
for i in range(len(X)):
    plt.plot([X.iloc[i, 0], X.iloc[i, 0]], [Y.iloc[i], model.predict(X)[i]], color='green', linestyle='dotted')

# Labels and title
plt.xlabel('Trip_Distance_km')
plt.ylabel('Trip_Price')
plt.title('Regression Line and Errors')
plt.legend()
plt.show()
